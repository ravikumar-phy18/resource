# %% [markdown]
# # Contour Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

f= lambda x,y : np.sin(x)*np.cos(y)
x=np.linspace(-np.pi,np.pi,100)
y=np.linspace(-np.pi,np.pi,100)

X,Y=np.meshgrid(x,y)

Z=f(X,Y)

plt.contour(X,Y,Z,10)
plt.show()

# %% [markdown]
# # Surface Plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

f= lambda x,y : np.sin(x)*np.cos(y)
x=np.linspace(-np.pi,np.pi,100)
y=np.linspace(-np.pi,np.pi,100)

X,Y=np.meshgrid(x,y)

Z=f(X,Y)


fig=plt.figure(figsize=[12,8])
ax=fig.gca(projection="3d")
ax.plot_surface(X,Y,Z,cmap=cm.coolwarm)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

f= lambda x,y : np.sin(x)*np.cos(y)
x=np.linspace(-np.pi,np.pi,100)
y=np.linspace(-np.pi,np.pi,100)

X,Y=np.meshgrid(x,y)

Z=f(X,Y)

def plotter(P,A):
    fig=plt.figure(figsize=[12,8])
    ax=fig.gca(projection="3d")
    ax.plot_surface(X,Y,Z,cmap=cm.coolwarm)
    ax.view_init(elev=P,azim=A)
    plt.show()

# %%
from ipywidgets import interactive
iplot = interactive(plotter,P=(-90,90,2.5),A=(-90,90,2.5))
iplot
# Out:
# interactive(children=(FloatSlider(value=0.0, description='P', max=90.0, min=-90.0, step=2.5), FloatSlider(valu…
